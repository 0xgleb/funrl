# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL/blob/master/Stock_NeurIPS2018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Task Description](#0)
# * [2. Install Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. A List of Python Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download and Preprocess Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5. Build Market Environment in OpenAI Gym-style](#4)
#     * [5.1. Data Split](#4.1)
#     * [5.3. Environment for Training](#4.2)
# * [6. Train DRL Agents](#5)
# * [7. Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Task Discription

# %% [markdown]
# We train a DRL agent for stock trading. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#
# The data for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Install Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install packages

# %%
## install finrl library
# !pip install wrds
# !pip install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# !pip install wandb
# Out:
# Requirement already satisfied: wrds in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (3.1.5)
# Requirement already satisfied: numpy in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wrds) (1.24.2)
# Requirement already satisfied: psycopg2-binary in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wrds) (2.9.5)
# Requirement already satisfied: sqlalchemy<2 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wrds) (1.4.46)
# Requirement already satisfied: scipy in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wrds) (1.10.0)
# Requirement already satisfied: pandas in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wrds) (1.5.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from sqlalchemy<2->wrds) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from pandas->wrds) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->wrds) (1.16.0)
# Requirement already satisfied: swig in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (4.1.1)
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /private/var/folders/40/f2pxj1q527xcry50w8frhdkh0000gn/T/pip-req-build-_jb6v1bl
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /private/var/folders/40/f2pxj1q527xcry50w8frhdkh0000gn/T/pip-req-build-_jb6v1bl
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 55948963d87a967b6952364f3344d0576fe5af14
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2
#   Cloning https://github.com/quantopian/pyfolio.git to /private/var/folders/40/f2pxj1q527xcry50w8frhdkh0000gn/T/pip-install-toa_5l9t/pyfolio_2adf3362ea59479992481075e7ce8d8c
#   Running command git clone --filter=blob:none --quiet https://github.com/quantopian/pyfolio.git /private/var/folders/40/f2pxj1q527xcry50w8frhdkh0000gn/T/pip-install-toa_5l9t/pyfolio_2adf3362ea59479992481075e7ce8d8c
#   Resolved https://github.com/quantopian/pyfolio.git to commit 4b901f6d73aa02ceb6d04b7d83502e5c6f2e81aa
#   Preparing metadata (setup.py) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /private/var/folders/40/f2pxj1q527xcry50w8frhdkh0000gn/T/pip-install-toa_5l9t/elegantrl_128df986c4764391a2171924b91e52b2
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /private/var/folders/40/f2pxj1q527xcry50w8frhdkh0000gn/T/pip-install-toa_5l9t/elegantrl_128df986c4764391a2171924b91e52b2
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 68bf0ea4ef3fb461026ece8897deabb92aeead32
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ccxt>=1.66.32 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (2.8.16)
# Requirement already satisfied: numpy>=1.17.3 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (1.24.2)
# Requirement already satisfied: stockstats>=0.4.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (0.5.2)
# Requirement already satisfied: gputil in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (1.4.0)
# Requirement already satisfied: exchange_calendars==3.6.3 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (3.6.3)
# Requirement already satisfied: tensorboardX in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (2.6)
# Requirement already satisfied: alpaca_trade_api>=2.1.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (2.3.0)
# Requirement already satisfied: lz4 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (4.3.2)
# Requirement already satisfied: pandas>=1.1.5 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (1.5.3)
# Requirement already satisfied: ray[default,tune]>=2.0.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (2.2.0)
# Requirement already satisfied: gym>=0.17 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (0.21.0)
# Requirement already satisfied: jqdatasdk in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (1.8.11)
# Requirement already satisfied: yfinance in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (0.2.12)
# Requirement already satisfied: importlib-metadata==4.13.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (4.13.0)
# Requirement already satisfied: stable-baselines3<2.0.0,>=1.6.2 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (1.7.0)
# Requirement already satisfied: matplotlib in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (3.7.0)
# Requirement already satisfied: scikit-learn>=0.21.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from finrl==0.3.5) (1.2.1)
# Requirement already satisfied: korean-lunar-calendar in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (0.3.1)
# Requirement already satisfied: pytz in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (2022.7.1)
# Requirement already satisfied: toolz in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (0.12.0)
# Requirement already satisfied: python-dateutil in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (2.8.2)
# Requirement already satisfied: pyluach in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from exchange_calendars==3.6.3->finrl==0.3.5) (2.1.0)
# Requirement already satisfied: zipp>=0.5 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from importlib-metadata==4.13.0->finrl==0.3.5) (3.14.0)
# Requirement already satisfied: requests<3,>2 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.28.2)
# Requirement already satisfied: msgpack==1.0.3 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.0.3)
# Requirement already satisfied: deprecation==2.1.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.1.0)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.5.1)
# Requirement already satisfied: urllib3<2,>1.24 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.26.14)
# Requirement already satisfied: websockets<11,>=9.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (10.4)
# Requirement already satisfied: aiohttp==3.8.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (3.8.1)
# Requirement already satisfied: PyYAML==6.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (6.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from aiohttp==3.8.1->alpaca_trade_api>=2.1.0->finrl==0.3.5) (6.0.4)
# Requirement already satisfied: packaging in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from deprecation==2.1.0->alpaca_trade_api>=2.1.0->finrl==0.3.5) (23.0)
# Requirement already satisfied: certifi>=2018.1.18 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (2022.12.7)
# Requirement already satisfied: setuptools>=60.9.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (65.6.3)
# Requirement already satisfied: aiodns>=1.1.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (3.0.0)
# Requirement already satisfied: cryptography>=2.6.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (39.0.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from gym>=0.17->finrl==0.3.5) (2.2.1)
# Requirement already satisfied: click>=7.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (8.1.3)
# Requirement already satisfied: virtualenv>=20.0.24 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (20.19.0)
# Requirement already satisfied: filelock in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (3.9.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (3.20.3)
# Requirement already satisfied: grpcio>=1.32.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (1.51.1)
# Requirement already satisfied: jsonschema in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (4.17.3)
# Requirement already satisfied: prometheus-client<0.14.0,>=0.7.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.13.1)
# Requirement already satisfied: pydantic in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (1.10.5)
# Requirement already satisfied: smart-open in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (6.3.0)
# Requirement already satisfied: colorful in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.5.5)
# Requirement already satisfied: gpustat>=1.0.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (1.0.0)
# Requirement already satisfied: py-spy>=0.2.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.3.14)
# Requirement already satisfied: aiohttp-cors in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.7.0)
# Requirement already satisfied: opencensus in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.11.1)
# Requirement already satisfied: tabulate in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ray[default,tune]>=2.0.0->finrl==0.3.5) (0.9.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (3.1.0)
# Requirement already satisfied: torch>=1.11 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from stable-baselines3<2.0.0,>=1.6.2->finrl==0.3.5) (1.13.1)
# Requirement already satisfied: thriftpy2>=0.3.9 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from jqdatasdk->finrl==0.3.5) (0.4.16)
# Requirement already satisfied: pymysql>=0.7.6 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from jqdatasdk->finrl==0.3.5) (1.0.2)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from jqdatasdk->finrl==0.3.5) (1.4.46)
# Requirement already satisfied: six in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from jqdatasdk->finrl==0.3.5) (1.16.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from matplotlib->finrl==0.3.5) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from matplotlib->finrl==0.3.5) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from matplotlib->finrl==0.3.5) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from matplotlib->finrl==0.3.5) (4.38.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from matplotlib->finrl==0.3.5) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from matplotlib->finrl==0.3.5) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from matplotlib->finrl==0.3.5) (9.4.0)
# Requirement already satisfied: ipython>=3.2.3 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (8.10.0)
# Requirement already satisfied: seaborn>=0.7.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.12.2)
# Requirement already satisfied: empyrical>=0.5.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.5.5)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from yfinance->finrl==0.3.5) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from yfinance->finrl==0.3.5) (4.9.2)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from yfinance->finrl==0.3.5) (0.0.11)
# Requirement already satisfied: html5lib>=1.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from yfinance->finrl==0.3.5) (1.1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from yfinance->finrl==0.3.5) (2.3.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from yfinance->finrl==0.3.5) (4.11.2)
# Requirement already satisfied: pycares>=4.0.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from aiodns>=1.1.1->ccxt>=1.66.32->finrl==0.3.5) (4.3.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from beautifulsoup4>=4.11.1->yfinance->finrl==0.3.5) (2.4)
# Requirement already satisfied: cffi>=1.12 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from cryptography>=2.6.1->ccxt>=1.66.32->finrl==0.3.5) (1.15.1)
# Requirement already satisfied: pandas-datareader>=0.2 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from empyrical>=0.5.0->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.10.0)
# Requirement already satisfied: nvidia-ml-py<=11.495.46,>=11.450.129 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from gpustat>=1.0.0->ray[default,tune]>=2.0.0->finrl==0.3.5) (11.495.46)
# Requirement already satisfied: psutil>=5.6.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from gpustat>=1.0.0->ray[default,tune]>=2.0.0->finrl==0.3.5) (5.9.4)
# Requirement already satisfied: blessed>=1.17.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from gpustat>=1.0.0->ray[default,tune]>=2.0.0->finrl==0.3.5) (1.20.0)
# Requirement already satisfied: webencodings in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from html5lib>=1.1->yfinance->finrl==0.3.5) (0.5.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (2.14.0)
# Requirement already satisfied: pickleshare in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.5)
# Requirement already satisfied: appnope in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.1.3)
# Requirement already satisfied: decorator in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (5.1.1)
# Requirement already satisfied: backcall in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.1.6)
# Requirement already satisfied: stack-data in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (5.9.0)
# Requirement already satisfied: jedi>=0.16 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (4.8.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (3.0.36)
# Requirement already satisfied: idna<4,>=2.5 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from requests<3,>2->alpaca_trade_api>=2.1.0->finrl==0.3.5) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from SQLAlchemy>=1.2.8->jqdatasdk->finrl==0.3.5) (2.0.2)
# Requirement already satisfied: ply<4.0,>=3.4 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from thriftpy2>=0.3.9->jqdatasdk->finrl==0.3.5) (3.11)
# Requirement already satisfied: typing-extensions in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3<2.0.0,>=1.6.2->finrl==0.3.5) (4.4.0)
# Requirement already satisfied: platformdirs<4,>=2.4 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from virtualenv>=20.0.24->ray[default,tune]>=2.0.0->finrl==0.3.5) (3.0.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from virtualenv>=20.0.24->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.3.6)
# Requirement already satisfied: pyglet>=1.4.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from gym>=0.17->finrl==0.3.5) (2.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from gym>=0.17->finrl==0.3.5) (2.3.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from jsonschema->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.19.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from jsonschema->ray[default,tune]>=2.0.0->finrl==0.3.5) (1.3.10)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (2.11.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.1.3)
# Requirement already satisfied: wcwidth>=0.1.4 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.2.6)
# Requirement already satisfied: pycparser in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt>=1.66.32->finrl==0.3.5) (2.21)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (2.16.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (1.58.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.0)
# Requirement already satisfied: pure-eval in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from stack-data->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from stack-data->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from stack-data->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (2.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (5.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]>=2.0.0->finrl==0.3.5) (0.4.8)
# Collecting wandb
#   Downloading wandb-0.13.10-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 2.8 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Requirement already satisfied: typing-extensions in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wandb) (4.4.0)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-macosx_10_9_x86_64.whl (11 kB)
# Collecting pathtools
#   Using cached pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: appdirs>=1.4.3 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wandb) (1.4.4)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.15.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wandb) (3.20.3)
# Collecting docker-pycreds>=0.4.0
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: setuptools in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wandb) (65.6.3)
# Requirement already satisfied: PyYAML in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wandb) (6.0)
# Requirement already satisfied: psutil>=5.0.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wandb) (5.9.4)
# Requirement already satisfied: requests<3,>=2.0.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wandb) (2.28.2)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from wandb) (8.1.3)
# Requirement already satisfied: six>=1.4.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=47e731e0204d00bf2a792c185613bd30f1157ee65034d4dfcf67cce4eb8f1409
#   Stored in directory: /Users/glebdianov/Library/Caches/pip/wheels/4d/33/74/7c0903053e955973d5dc3d21857a29b3f8c0806ad0b05c32a1
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.31 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.15.0 setproctitle-1.3.2 smmap-5.0.0 wandb-0.13.10

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: gleb-dianov (intelligent-systems). Use `wandb login --relogin` to force relogin

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. A list of Python packages
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
import wandb

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance provides stock data, financial news, financial reports, etc. Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** in FinRL-Meta to fetch data via Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
# from config.py, TRAIN_START_DATE is a string
TRAIN_START_DATE
# from config.py, TRAIN_END_DATE is a string
TRAIN_END_DATE
# Out:
# '2020-07-31'

# %%
TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2020-07-01'
TRADE_START_DATE = '2020-07-01'
TRADE_END_DATE = '2021-10-31'

# %%
df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# Shape of DataFrame:  (94331, 8)

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
df.shape
# Out:
# (94331, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.758535  746015200  AAPL
# 1  2009-01-02  58.590000  59.080002  57.750000  43.832638    6547900  AMGN
# 2  2009-01-02  18.570000  19.520000  18.400000  15.365307   10955700   AXP
# 3  2009-01-02  42.799999  45.560001  42.779999  33.941097    7010200    BA
# 4  2009-01-02  44.910000  46.980000  44.709999  31.579340    7117200   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %% [markdown]
# # Part 4: Preprocess Data
# We need to check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3229, 8)
# Successfully added vix
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#          date   tic       open       high        low      close       volume  \
# 0  2009-01-02  AAPL   3.067143   3.251429   3.041429   2.758535  746015200.0
# 1  2009-01-02  AMGN  58.590000  59.080002  57.750000  43.832638    6547900.0
# 2  2009-01-02   AXP  18.570000  19.520000  18.400000  15.365307   10955700.0
# 3  2009-01-02    BA  42.799999  45.560001  42.779999  33.941097    7010200.0
# 4  2009-01-02   CAT  44.910000  46.980000  44.709999  31.579340    7117200.0
# 5  2009-01-02   CRM   8.025000   8.550000   7.912500   8.505000    4069200.0
# 6  2009-01-02  CSCO  16.410000  17.000000  16.250000  11.948335   40980600.0
# 7  2009-01-02   CVX  74.230003  77.300003  73.580002  43.677185   13695900.0
# 8  2009-01-02   DIS  22.760000  24.030001  22.500000  20.597496    9796600.0
# 9  2009-01-02    GS  84.019997  87.620003  82.190002  69.747620   14088500.0
#
#    day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  4.0   0.0  2.981388  2.652103   100.0  66.666667  100.0      2.758535
# 1  4.0   0.0  2.981388  2.652103   100.0  66.666667  100.0     43.832638
# 2  4.0   0.0  2.981388  2.652103   100.0  66.666667  100.0     15.365307
# 3  4.0   0.0  2.981388  2.652103   100.0  66.666667  100.0     33.941097
# 4  4.0   0.0  2.981388  2.652103   100.0  66.666667  100.0     31.579340
# 5  4.0   0.0  2.981388  2.652103   100.0  66.666667  100.0      8.505000
# 6  4.0   0.0  2.981388  2.652103   100.0  66.666667  100.0     11.948335
# 7  4.0   0.0  2.981388  2.652103   100.0  66.666667  100.0     43.677185
# 8  4.0   0.0  2.981388  2.652103   100.0  66.666667  100.0     20.597496
# 9  4.0   0.0  2.981388  2.652103   100.0  66.666667  100.0     69.747620
#
#    close_60_sma        vix  turbulence
# 0      2.758535  39.189999         0.0
# 1     43.832638  39.189999         0.0
# 2     15.365307  39.189999         0.0
# 3     33.941097  39.189999         0.0
# 4     31.579340  39.189999         0.0
# 5      8.505000  39.189999         0.0
# 6     11.948335  39.189999         0.0
# 7     43.677185  39.189999         0.0
# 8     20.597496  39.189999         0.0
# 9     69.747620  39.189999         0.0

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 83897
# 9744

# %%
train.tail()
# Out:
#             date  tic        open        high         low       close  \
# 2892  2020-06-30  UNH  288.570007  296.450012  287.660004  284.978790
# 2892  2020-06-30    V  191.490005  193.750000  190.160004  189.603989
# 2892  2020-06-30   VZ   54.919998   55.290001   54.360001   48.169014
# 2892  2020-06-30  WBA   42.119999   42.580002   41.759998   37.630482
# 2892  2020-06-30  WMT  119.220001  120.129997  118.540001  115.183998
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30     cci_30  \
# 2892   2932900.0  1.0 -0.019281  300.970799  268.613891  52.413060 -25.914708
# 2892   9040100.0  1.0  1.042554  197.569693  183.942018  53.021022 -51.608505
# 2892  17414800.0  1.0 -0.417955   51.555485   46.593787  48.097048 -51.186625
# 2892   4782100.0  1.0 -0.080962   41.075405   35.173593  48.830184 -14.613187
# 2892   6836400.0  1.0 -0.879411  118.508926  112.593778  48.159658 -69.964839
#
#          dx_30  close_30_sma  close_60_sma    vix  turbulence
# 2892  1.846804    285.220265    278.269265  30.43   12.918862
# 2892  2.013358    190.347370    180.598286  30.43   12.918862
# 2892  8.508886     48.776547     49.209270  30.43   12.918862
# 2892  1.500723     37.726357     37.533499  30.43   12.918862
# 2892  3.847271    116.836411    118.756426  30.43   12.918862

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.494576
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  234.614304
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   91.078476
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  118.455795
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.000855   92.276534   79.814272  62.807167  107.499113
# 0    6575800.0  2.0  3.552506  227.036696  195.594643  61.279628  270.849099
# 0    3301000.0  2.0 -0.384902  109.215321   86.798781  48.504822  -66.306127
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.249468  128.246933  111.290114  52.865423   35.692991
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.550963     77.363089  28.620001   53.068108
# 0  46.806139    209.902517    210.950772  28.620001   53.068108
# 0   3.142448     96.180266     89.702836  28.620001   53.068108
# 0  15.932920    176.472335    155.614168  28.620001   53.068108
# 0  14.457404    117.239537    111.578318  28.620001   53.068108

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

if_using_a2c = False
if_using_ddpg = False
if_using_ppo = False
if_using_td3 = False
if_using_sac = True

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000) if if_using_ppo else None

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=30000) if if_using_td3 else None

# %% [markdown]
# ### Agent 5: SAC

# %%
# %pip install tensorboard
# Out:
# Requirement already satisfied: tensorboard in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (2.12.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (0.7.0)
# Requirement already satisfied: protobuf>=3.19.6 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (2.2.3)
# Requirement already satisfied: wheel>=0.26 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (0.38.4)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (1.51.1)
# Requirement already satisfied: numpy>=1.12.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (1.24.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (2.16.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (65.6.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from tensorboard) (2.28.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard) (4.13.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.14.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to results/sac

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=40000) if if_using_sac else None
# Out:
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 32         |
# |    time_elapsed    | 361        |
# |    total_timesteps | 11572      |
# | train/             |            |
# |    actor_loss      | 1.77e+03   |
# |    critic_loss     | 152        |
# |    ent_coef        | 0.276      |
# |    ent_coef_loss   | 147        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 11471      |
# |    reward          | -27.677353 |
# -----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 31        |
# |    time_elapsed    | 740       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | 940       |
# |    critic_loss     | 324       |
# |    ent_coef        | 0.129     |
# |    ent_coef_loss   | -95.7     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 23043     |
# |    reward          | 1.9785506 |
# ----------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 3389600.25
# total_reward: 2389600.25
# total_cost: 48785.52
# total_trades: 58783
# Sharpe: 0.654
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 30       |
# |    time_elapsed    | 1148     |
# |    total_timesteps | 34716    |
# | train/             |          |
# |    actor_loss      | 504      |
# |    critic_loss     | 29.7     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | -131     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 34615    |
# |    reward          | 5.455569 |
# ---------------------------------

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data. If current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<TRAIN_END_DATE) & (processed_full.date>=TRAIN_START_DATE)]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    2893.000000
# mean       18.824245
# std         8.489311
# min         9.140000
# 25%        13.330000
# 50%        16.139999
# 75%        21.309999
# max        82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# 57.40400183105453

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    2893.000000
# mean       34.567954
# std        43.790779
# min         0.000000
# 25%        14.962625
# 50%        24.124192
# 75%        39.162156
# max       652.505085
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# 276.4509652847886

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.494576
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  234.614304
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   91.078476
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  118.455795
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.000855   92.276534   79.814272  62.807167  107.499113
# 0    6575800.0  2.0  3.552506  227.036696  195.594643  61.279628  270.849099
# 0    3301000.0  2.0 -0.384902  109.215321   86.798781  48.504822  -66.306127
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.249468  128.246933  111.290114  52.865423   35.692991
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.550963     77.363089  28.620001   53.068108
# 0  46.806139    209.902517    210.950772  28.620001   53.068108
# 0   3.142448     96.180266     89.702836  28.620001   53.068108
# 0  15.932920    176.472335    155.614168  28.620001   53.068108
# 0  14.457404    117.239537    111.578318  28.620001   53.068108

# %%
trained_moedl = trained_sac
df_account_value, df_actions = DRLAgent.DRL_prediction(
    model=trained_moedl, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
df_account_value.shape
# Out:
# (336, 2)

# %%
df_account_value.tail()
# Out:
#            date  account_value
# 331  2021-10-22   1.384067e+06
# 332  2021-10-25   1.383721e+06
# 333  2021-10-26   1.380265e+06
# 334  2021-10-27   1.372582e+06
# 335  2021-10-28   1.380977e+06

# %%
df_actions.head()
# Out:
#             AAPL  AMGN  AXP  BA  CAT  CRM  CSCO  CVX  DIS  GS  ...  MRK  MSFT  \
# date                                                           ...
# 2020-07-01    58     0   25  76    4    0     0    0   48  55  ...    0    59
# 2020-07-02    58     0   25  76    4    0     0    0   48  55  ...    0    59
# 2020-07-06    58     0   25  76    4    0     0    0   48  55  ...    0    59
# 2020-07-07    58     0   25  76    4    0     0    0   48  55  ...    0    59
# 2020-07-08    58     0   25  76    4    0     0    0   48  55  ...    0    59
#
#             NKE  PG  TRV  UNH   V  VZ  WBA  WMT
# date
# 2020-07-01   52   0   21   82  23   0    0    0
# 2020-07-02   52   0   21   82  23   0    0    0
# 2020-07-06   52   0   21   82  23   0    0    0
# 2020-07-07   52   0   21   82  23   0    0    0
# 2020-07-08   52   0   21   82  23   0    0    0
#
# [5 rows x 29 columns]

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.273913
# Cumulative returns     0.380977
# Annual volatility      0.152465
# Sharpe ratio           1.669403
# Calmar ratio           3.097649
# Stability              0.918797
# Max drawdown          -0.088426
# Omega ratio            1.316493
# Sortino ratio          2.517986
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.100093
# Daily value at risk   -0.018199
# dtype: float64
# /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (335, 8)
# Annual return          0.273520
# Cumulative returns     0.379084
# Annual volatility      0.139248
# Sharpe ratio           1.811893
# Calmar ratio           3.062662
# Stability              0.918651
# Max drawdown          -0.089308
# Omega ratio            1.351851
# Sortino ratio          2.684720
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.051856
# Daily value at risk   -0.016542
# dtype: float64
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()

# %%
df_account_value.loc[0,'date']
# Out:
# '2020-07-01'

# %%
df_account_value.loc[len(df_account_value)-1,'date']
# Out:
# '2021-10-28'

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (335, 8)
# /Users/glebdianov/code/gleb/funrl/finrl/meta/preprocessor/yahoodownloader.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()
# /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages/pyfolio/plotting.py:648: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for stat, value in perf_stats[column].iteritems():
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-28</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>16</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>27.391%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>38.098%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>15.246%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.67</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>3.10</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.843%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.32</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.52</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.10</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.82%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.01</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.03</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.84</td>
#       <td>2020-10-12</td>
#       <td>2020-10-30</td>
#       <td>2020-11-09</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>8.10</td>
#       <td>2020-09-02</td>
#       <td>2020-09-23</td>
#       <td>2020-10-12</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.75</td>
#       <td>2021-08-12</td>
#       <td>2021-09-21</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.51</td>
#       <td>2021-01-21</td>
#       <td>2021-01-29</td>
#       <td>2021-02-08</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.03</td>
#       <td>2020-07-22</td>
#       <td>2020-07-31</td>
#       <td>2020-08-06</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages/pyfolio/plotting.py:805: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   oos_cum_returns = pd.Series([])
# /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages/pyfolio/plotting.py:805: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   oos_cum_returns = pd.Series([])
# /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages/pyfolio/plotting.py:805: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   oos_cum_returns = pd.Series([])
# /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages/pyfolio/timeseries.py:541: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   out = pd.Series(index=returns.index)
# /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages/pyfolio/timeseries.py:541: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   out = pd.Series(index=returns.index)
# /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages/pyfolio/timeseries.py:1230: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   period = returns_dupe.loc[start:end]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.10%</td>
#       <td>-3.70%</td>
#       <td>2.90%</td>
#     </tr>
#   </tbody>
# </table>
# /Users/glebdianov/opt/miniconda3/envs/funrl/lib/python3.8/site-packages/pyfolio/timeseries.py:1230: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   period = returns_dupe.loc[start:end]
